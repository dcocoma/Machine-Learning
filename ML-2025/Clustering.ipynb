# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.io import arff
# Parser un fichier de donnees au format arff
# data est un tableau d ’ exemples avec pour chacun
# la liste des valeurs des features
#
# Dans les jeux de donnees consideres :
# il y a 2 features ( dimension 2 )
# Ex : [[ - 0 . 499261 , -0 . 0612356 ] ,
# [ - 1 . 51369 , 0 . 265446 ] ,
# [ - 1 . 60321 , 0 . 362039 ] , .....
# ]
#
# Note : chaque exemple du jeu de donnees contient aussi un
# numero de cluster . On retire cette information
path = './'
databrut = arff.loadarff(open(path+"xclara.arff",'r'))
#datanp = [[x[0],x[1]] for x in databrut[0]]
datanp = np.array([[x[0], x[1]] for x in databrut[0]])  # <-- conversion en numpy array
# Affichage en 2D
# Extraire chaque valeur de features pour en faire une liste
# Ex pour f0 = [ - 0 . 499261 , -1 . 51369 , -1 . 60321 , ...]
# Ex pour f1 = [ - 0 . 0612356 , 0 . 265446 , 0 . 362039 , ...]
f0 = datanp[:,0] # tous les elements de la premiere colonne
f1 = datanp[:,1] # tous les elements de la deuxieme colonne
plt.scatter(f0,f1,s=8)
plt.title("Donnees initiales")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import time
from sklearn import cluster

# Les donnees sont dans datanp ( 2 dimensions )
# f0 : valeurs sur la premiere dimension
# f1 : valeur sur la deuxieme dimension

print ( " Appel KMeans pour une valeur fixee de k " )
tps1 = time.time()
k = 3
model = cluster.KMeans(n_clusters=k, init ='k-means++')
model.fit(datanp)
tps2 = time.time()
labels = model.labels_
iteration = model.n_iter_
plt.scatter(f0,f1, c = labels, s = 8 )
plt.title( " Donnees apres clustering Kmeans " )
plt.show()
print( "nb clusters = " ,k , ", nb iter = " ,iteration , ", runtime = " , round((tps2 - tps1) * 1000 , 2 ) ," ms " )
# Out:
#  Appel KMeans pour une valeur fixee de k
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# nb clusters =  3 , nb iter =  3 , runtime =  29.28  ms

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.io import arff
# Parser un fichier de donnees au format arff
# data est un tableau d ’ exemples avec pour chacun
# la liste des valeurs des features
#
# Dans les jeux de donnees consideres :
# il y a 2 features ( dimension 2 )
# Ex : [[ - 0 . 499261 , -0 . 0612356 ] ,
# [ - 1 . 51369 , 0 . 265446 ] ,
# [ - 1 . 60321 , 0 . 362039 ] , .....
# ]
#
# Note : chaque exemple du jeu de donnees contient aussi un
# numero de cluster . On retire cette information
path = './'
databrut = arff.loadarff(open(path+"s-set1.arff",'r'))
#datanp = [[x[0],x[1]] for x in databrut[0]]
datanp = np.array([[x[0], x[1]] for x in databrut[0]])  # <-- conversion en numpy array
# Affichage en 2D
# Extraire chaque valeur de features pour en faire une liste
# Ex pour f0 = [ - 0 . 499261 , -1 . 51369 , -1 . 60321 , ...]
# Ex pour f1 = [ - 0 . 0612356 , 0 . 265446 , 0 . 362039 , ...]
f0 = datanp[:,0] # tous les elements de la premiere colonne
f1 = datanp[:,1] # tous les elements de la deuxieme colonne
plt.scatter(f0,f1,s=8)
plt.title("Donnees initiales")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import time
from sklearn.metrics import silhouette_score 
from sklearn import cluster

# Les donnees sont dans datanp ( 2 dimensions )
# f0 : valeurs sur la premiere dimension
# f1 : valeur sur la deuxieme dimension
A = np.zeros((20, 2))
B = np.zeros((20, 2))
print ( " Appel KMeans pour une valeur fixee de k " )
for i in range(3,23):
    k = i
    tps1 = time.time()
    #k = 3
    model = cluster.KMeans(n_clusters=k, init ='k-means++')
    model.fit(datanp)
    tps2 = time.time()
    labels = model.labels_
    iteration = model.n_iter_
    score = silhouette_score(datanp,labels)
    #plt.scatter(f0,f1, c = labels, s = 8 )
    #plt.title( " Donnees apres clustering Kmeans " )
    #plt.show()
    tim = round((tps2 - tps1) * 1000 , 2 )
    print( "nb clusters = " ,k , ", nb iter = " ,iteration , ", runtime = " , tim ," ms, score : ", score )
    A[k-3,0] = k
    A[k-3,1] = score
    B[k-3,0] = k
    B[k-3,1] = tim
# Out:
#  Appel KMeans pour une valeur fixee de k
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# nb clusters =  3 , nb iter =  17 , runtime =  39.16  ms, score :  0.41529477430840245
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# nb clusters =  4 , nb iter =  9 , runtime =  28.7  ms, score :  0.44523116293878723
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# nb clusters =  5 , nb iter =  9 , runtime =  31.93  ms, score :  0.46392568634109593
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# nb clusters =  6 , nb iter =  9 , runtime =  31.05  ms, score :  0.49470981807487335
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# nb clusters =  7 , nb iter =  11 , runtime =  35.26  ms, score :  0.5276924216832588
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# nb clusters =  8 , nb iter =  6 , runtime =  33.65  ms, score :  0.5665265467956482
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# nb clusters =  9 , nb iter =  10 , runtime =  41.53  ms, score :  0.5829681076853106
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# nb clusters =  10 , nb iter =  6 , runtime =  39.26  ms, score :  0.603245929989823
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# nb clusters =  11 , nb iter =  9 , runtime =  39.88  ms, score :  0.6203280463840423
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# nb clusters =  12 , nb iter =  5 , runtime =  45.14  ms, score :  0.6440425484320176
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# nb clusters =  13 , nb iter =  4 , runtime =  41.3  ms, score :  0.6490573751290334
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# nb clusters =  14 , nb iter =  4 , runtime =  46.0  ms, score :  0.6898844415289176
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# nb clusters =  15 , nb iter =  3 , runtime =  48.95  ms, score :  0.711278614093076
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# nb clusters =  16 , nb iter =  3 , runtime =  49.11  ms, score :  0.6853651387150171
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# nb clusters =  17 , nb iter =  7 , runtime =  59.8  ms, score :  0.6717766656778769
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# nb clusters =  18 , nb iter =  13 , runtime =  55.35  ms, score :  0.6427193053449654
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# nb clusters =  19 , nb iter =  9 , runtime =  66.91  ms, score :  0.614177429659077
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# nb clusters =  20 , nb iter =  16 , runtime =  61.54  ms, score :  0.6145045176958481
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# nb clusters =  21 , nb iter =  11 , runtime =  67.17  ms, score :  0.5987931807443375
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# nb clusters =  22 , nb iter =  12 , runtime =  70.05  ms, score :  0.5383586041315663

# %%
plt.plot(A[:,0], A[:, 1], marker='o')
plt.grid(True, which='both', linestyle='--', alpha=0.6)
plt.title("k-means plot s-set1")
plt.xlabel("k")
plt.ylabel("silhouette score")
plt.xticks(range(int(min(A[:,0])), int(max(A[:,0])) + 1))
plt.xscale

plt.figure()
plt.plot(B[:,0], B[:, 1])
plt.grid(True, which='both', linestyle='--', alpha=0.6)
plt.title("k-means excecution time plot s-set1")
plt.xlabel("k")
plt.ylabel("silhouette score")
plt.xticks(range(int(min(B[:,0])), int(max(B[:,0])) + 1))
plt.xscale
# Out:
# <function matplotlib.pyplot.xscale(value: 'str | ScaleBase', **kwargs) -> 'None'>

# %%
path = './'
databrut = arff.loadarff(open(path+"mopsi-finland.arff",'r'))
datanp = np.array([[x[0], x[1]] for x in databrut[0]])  # <-- conversion en numpy array
f0 = datanp[:,0] # tous les elements de la premiere colonne
f1 = datanp[:,1] # tous les elements de la deuxieme colonne
A2 = np.zeros((20, 2))
B2 = np.zeros((20, 2))
print ( " Appel KMeans pour une valeur fixee de k " )
for i in range(3,23):
    k = i
    tps1 = time.time()
    #k = 3
    model = cluster.KMeans(n_clusters=k, init ='k-means++')
    model.fit(datanp)
    tps2 = time.time()
    labels = model.labels_
    iteration = model.n_iter_
    score = silhouette_score(datanp,labels)
    #plt.scatter(f0,f1, c = labels, s = 8 )
    #plt.title( " Donnees apres clustering Kmeans " )
    #plt.show()
    tim = round((tps2 - tps1) * 1000 , 2 )
    print( "nb clusters = " ,k , ", nb iter = " ,iteration , ", runtime = " , tim ," ms, score : ", score )
    A2[k-3,0] = k
    A2[k-3,1] = score
    B2[k-3,0] = k
    B2[k-3,1] = tim
# Out:
#  Appel KMeans pour une valeur fixee de k
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# nb clusters =  3 , nb iter =  4 , runtime =  32.63  ms, score :  0.8015256665857015
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# nb clusters =  4 , nb iter =  9 , runtime =  34.23  ms, score :  0.8076014334776523
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# nb clusters =  5 , nb iter =  5 , runtime =  34.01  ms, score :  0.7966975914352101
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# nb clusters =  6 , nb iter =  5 , runtime =  35.77  ms, score :  0.7987956884381984
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# nb clusters =  7 , nb iter =  6 , runtime =  49.46  ms, score :  0.8064948649598473
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# nb clusters =  8 , nb iter =  5 , runtime =  43.98  ms, score :  0.8183405226624324
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# nb clusters =  9 , nb iter =  5 , runtime =  48.18  ms, score :  0.7123177008229722
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# nb clusters =  10 , nb iter =  5 , runtime =  61.87  ms, score :  0.7276237847389126
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# nb clusters =  11 , nb iter =  9 , runtime =  54.73  ms, score :  0.7387489274197272
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# nb clusters =  12 , nb iter =  5 , runtime =  57.91  ms, score :  0.7600967123850544
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# nb clusters =  13 , nb iter =  8 , runtime =  67.34  ms, score :  0.7617208969799791
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# nb clusters =  14 , nb iter =  6 , runtime =  69.08  ms, score :  0.7672994871369526
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# nb clusters =  15 , nb iter =  7 , runtime =  73.81  ms, score :  0.7676153364641023
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# nb clusters =  16 , nb iter =  8 , runtime =  75.23  ms, score :  0.7729321243920716
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# nb clusters =  17 , nb iter =  8 , runtime =  75.72  ms, score :  0.7813344071305935
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# nb clusters =  18 , nb iter =  7 , runtime =  83.16  ms, score :  0.7760211168338883
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# nb clusters =  19 , nb iter =  8 , runtime =  86.23  ms, score :  0.7837019300776195
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# nb clusters =  20 , nb iter =  9 , runtime =  86.01  ms, score :  0.7782683536207323
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# nb clusters =  21 , nb iter =  6 , runtime =  101.57  ms, score :  0.7799424195511052
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# nb clusters =  22 , nb iter =  8 , runtime =  106.64  ms, score :  0.7809091599355613

# %%
plt.plot(A2[:,0], A2[:, 1], marker='o')
plt.grid(True, which='both', linestyle='--', alpha=0.6)
plt.title("k-means plot mopsi-finland")
plt.xlabel("k")
plt.ylabel("silhouette score")
plt.xticks(range(int(min(A2[:,0])), int(max(A2[:,0])) + 1))
plt.xscale

plt.figure()
plt.plot(B2[:,0], B2[:, 1])
plt.grid(True, which='both', linestyle='--', alpha=0.6)
plt.title("k-means excecution time plot mopsi-finland")
plt.xlabel("k")
plt.ylabel("silhouette score")
plt.xticks(range(int(min(B2[:,0])), int(max(B2[:,0])) + 1))
plt.xscale
# Out:
# <function matplotlib.pyplot.xscale(value: 'str | ScaleBase', **kwargs) -> 'None'>

# %%
path = './'
databrut = arff.loadarff(open(path+"smile1.arff",'r'))
datanp = np.array([[x[0], x[1]] for x in databrut[0]])  # <-- conversion en numpy array
f0 = datanp[:,0] # tous les elements de la premiere colonne
f1 = datanp[:,1] # tous les elements de la deuxieme colonne
A3 = np.zeros((20, 2))
B3 = np.zeros((20, 2))
print ( " Appel KMeans pour une valeur fixee de k " )
for i in range(3,23):
    k = i
    tps1 = time.time()
    #k = 3
    model = cluster.KMeans(n_clusters=k, init ='k-means++')
    model.fit(datanp)
    tps2 = time.time()
    labels = model.labels_
    iteration = model.n_iter_
    score = silhouette_score(datanp,labels)
    #plt.scatter(f0,f1, c = labels, s = 8 )
    #plt.title( " Donnees apres clustering Kmeans " )
    #plt.show()
    tim = round((tps2 - tps1) * 1000 , 2 )
    print( "nb clusters = " ,k , ", nb iter = " ,iteration , ", runtime = " , tim ," ms, score : ", score )
    A3[k-3,0] = k
    A3[k-3,1] = score
    B3[k-3,0] = k
    B3[k-3,1] = tim
# Out:
#  Appel KMeans pour une valeur fixee de k
# nb clusters =  3 , nb iter =  4 , runtime =  70.6  ms, score :  0.6393006957752178
# nb clusters =  4 , nb iter =  6 , runtime =  28.52  ms, score :  0.6263115016259269
# nb clusters =  5 , nb iter =  8 , runtime =  23.21  ms, score :  0.6360419791642773
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# nb clusters =  6 , nb iter =  12 , runtime =  23.88  ms, score :  0.6376087040170163
# nb clusters =  7 , nb iter =  9 , runtime =  31.91  ms, score :  0.6502637645755456
# nb clusters =  8 , nb iter =  21 , runtime =  26.8  ms, score :  0.6676205619750617
# nb clusters =  9 , nb iter =  7 , runtime =  26.32  ms, score :  0.6762609576943321
# nb clusters =  10 , nb iter =  9 , runtime =  26.98  ms, score :  0.6934783298020748
# nb clusters =  11 , nb iter =  10 , runtime =  29.03  ms, score :  0.7014328981371023
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# nb clusters =  12 , nb iter =  11 , runtime =  39.32  ms, score :  0.7053587780561187
# nb clusters =  13 , nb iter =  13 , runtime =  29.69  ms, score :  0.6998181919779859
# nb clusters =  14 , nb iter =  5 , runtime =  30.51  ms, score :  0.7058616791355269
# nb clusters =  15 , nb iter =  7 , runtime =  31.54  ms, score :  0.7069780721839205
# nb clusters =  16 , nb iter =  12 , runtime =  35.19  ms, score :  0.702606935863738
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# nb clusters =  17 , nb iter =  6 , runtime =  45.09  ms, score :  0.6992976392613105
# nb clusters =  18 , nb iter =  10 , runtime =  39.18  ms, score :  0.6986911437368303
# nb clusters =  19 , nb iter =  7 , runtime =  43.27  ms, score :  0.6993580513748062
# nb clusters =  20 , nb iter =  5 , runtime =  39.23  ms, score :  0.69783776944963
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# nb clusters =  21 , nb iter =  11 , runtime =  40.58  ms, score :  0.6978091678598071
# nb clusters =  22 , nb iter =  6 , runtime =  40.88  ms, score :  0.6972083810259223
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
plt.plot(A3[:,0], A3[:, 1], marker='o')
plt.grid(True, which='both', linestyle='--', alpha=0.6)
plt.title("k-means plot smile")
plt.xlabel("k")
plt.ylabel("silhouette score")
plt.xticks(range(int(min(A3[:,0])), int(max(A3[:,0])) + 1))
plt.xscale

plt.figure()
plt.plot(B3[:,0], B3[:, 1])
plt.grid(True, which='both', linestyle='--', alpha=0.6)
plt.title("k-means excecution time plot smile")
plt.xlabel("k")
plt.ylabel("silhouette score")
plt.xticks(range(int(min(B3[:,0])), int(max(B3[:,0])) + 1))
plt.xscale
# Out:
# <function matplotlib.pyplot.xscale(value: 'str | ScaleBase', **kwargs) -> 'None'>

# %%
path = './'
databrut = arff.loadarff(open(path+"smile1.arff",'r'))
#datanp = [[x[0],x[1]] for x in databrut[0]]
datanp = np.array([[x[0], x[1]] for x in databrut[0]])  # <-- conversion en numpy array
# Affichage en 2D
# Extraire chaque valeur de features pour en faire une liste
# Ex pour f0 = [ - 0 . 499261 , -1 . 51369 , -1 . 60321 , ...]
# Ex pour f1 = [ - 0 . 0612356 , 0 . 265446 , 0 . 362039 , ...]
f0 = datanp[:,0] # tous les elements de la premiere colonne
f1 = datanp[:,1] # tous les elements de la deuxieme colonne
print ( " Appel KMeans pour une valeur fixee de k = 15" )
tps1 = time.time()
k = 15
model = cluster.KMeans(n_clusters=k, init ='k-means++')
model.fit(datanp)
tps2 = time.time()
labels = model.labels_
iteration = model.n_iter_
plt.scatter(f0,f1, c = labels, s = 8 )
plt.title( " Donnees apres clustering Kmeans " )
plt.show()
print( "nb clusters = " ,k , ", nb iter = " ,iteration , ", runtime = " , round((tps2 - tps1) * 1000 , 2 ) ," ms " )
# Out:
#  Appel KMeans pour une valeur fixee de k = 15
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# nb clusters =  15 , nb iter =  9 , runtime =  120.49  ms

# %%
path = './'
databrut = arff.loadarff(open(path+"golfball.arff",'r'))
datanp = np.array([[x[0], x[1]] for x in databrut[0]])  # <-- conversion en numpy array
f0 = datanp[:,0] # tous les elements de la premiere colonne
f1 = datanp[:,1] # tous les elements de la deuxieme colonne
A4 = np.zeros((21, 2))
B4 = np.zeros((21, 2))
for i in range(2,23):
    k = i
    tps1 = time.time()
    #k = 3
    model = cluster.KMeans(n_clusters=k, init ='k-means++')
    model.fit(datanp)
    tps2 = time.time()
    labels = model.labels_
    iteration = model.n_iter_
    score = silhouette_score(datanp,labels)
    #plt.scatter(f0,f1, c = labels, s = 8 )
    #plt.title( " Donnees apres clustering Kmeans " )
    #plt.show()
    tim = round((tps2 - tps1) * 1000 , 2 )
    print( "nb clusters = " ,k , ", nb iter = " ,iteration , ", runtime = " , tim ," ms, score : ", score )
    A4[k-2,0] = k
    A4[k-2,1] = score
    B4[k-2,0] = k
    B4[k-2,1] = tim
# Out:
#  Appel KMeans pour une valeur fixee de k
# nb clusters =  2 , nb iter =  10 , runtime =  61.09  ms, score :  0.3636567117760847
# nb clusters =  3 , nb iter =  6 , runtime =  73.11  ms, score :  0.49747648143912815
# nb clusters =  4 , nb iter =  11 , runtime =  31.99  ms, score :  0.41941227532407427
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# nb clusters =  5 , nb iter =  10 , runtime =  22.67  ms, score :  0.38733117334113076
# nb clusters =  6 , nb iter =  22 , runtime =  25.41  ms, score :  0.3487635995801358
# nb clusters =  7 , nb iter =  9 , runtime =  23.18  ms, score :  0.37595203481682754
# nb clusters =  8 , nb iter =  18 , runtime =  24.22  ms, score :  0.365062419320836
# nb clusters =  9 , nb iter =  13 , runtime =  25.11  ms, score :  0.3629380165526612
# nb clusters =  10 , nb iter =  19 , runtime =  26.53  ms, score :  0.3666958902762821
# nb clusters =  11 , nb iter =  6 , runtime =  26.6  ms, score :  0.3626580231090342
# nb clusters =  12 , nb iter =  19 , runtime =  27.55  ms, score :  0.35957027979609923
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# nb clusters =  13 , nb iter =  10 , runtime =  34.49  ms, score :  0.36139481844512006
# nb clusters =  14 , nb iter =  6 , runtime =  27.05  ms, score :  0.3781537093904431
# nb clusters =  15 , nb iter =  11 , runtime =  28.08  ms, score :  0.37750754577105283
# nb clusters =  16 , nb iter =  13 , runtime =  29.26  ms, score :  0.36323306933650146
# nb clusters =  17 , nb iter =  17 , runtime =  30.17  ms, score :  0.3691572439331587
# nb clusters =  18 , nb iter =  12 , runtime =  30.97  ms, score :  0.3703949017514875
# nb clusters =  19 , nb iter =  19 , runtime =  31.49  ms, score :  0.37315401001739396
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# nb clusters =  20 , nb iter =  10 , runtime =  43.67  ms, score :  0.36485134784433754
# nb clusters =  21 , nb iter =  8 , runtime =  35.48  ms, score :  0.36571001057467356
# nb clusters =  22 , nb iter =  9 , runtime =  34.77  ms, score :  0.3821226024352282
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
plt.plot(A4[:,0], A4[:, 1], marker='o')
plt.grid(True, which='both', linestyle='--', alpha=0.6)
plt.title("k-means plot golfball")
plt.xlabel("k")
plt.ylabel("silhouette score")
plt.xticks(range(int(min(A4[:,0])), int(max(A4[:,0])) + 1))
plt.xscale

plt.figure()
plt.plot(B4[:,0], B4[:, 1])
plt.grid(True, which='both', linestyle='--', alpha=0.6)
plt.title("k-means excecution time plot golfball")
plt.xlabel("k")
plt.ylabel("silhouette score")
plt.xticks(range(int(min(B4[:,0])), int(max(B4[:,0])) + 1))
plt.xscale
# Out:
# <function matplotlib.pyplot.xscale(value: 'str | ScaleBase', **kwargs) -> 'None'>

# %%
path = './'
databrut = arff.loadarff(open(path+"golfball.arff",'r'))
datanp = np.array([[x[0], x[1]] for x in databrut[0]])  # <-- conversion en numpy array
f0 = datanp[:,0] # tous les elements de la premiere colonne
f1 = datanp[:,1] # tous les elements de la deuxieme colonne
print ( " Appel KMeans pour une valeur fixee de k = 3" )
tps1 = time.time()
k = 3
model = cluster.KMeans(n_clusters=k, init ='k-means++')
model.fit(datanp)
tps2 = time.time()
labels = model.labels_
iteration = model.n_iter_
plt.scatter(f0,f1, c = labels, s = 8 )
plt.title( " Donnees apres clustering Kmeans " )
plt.show()
print( "nb clusters = " ,k , ", nb iter = " ,iteration , ", runtime = " , round((tps2 - tps1) * 1000 , 2 ) ," ms " )
# Out:
#  Appel KMeans pour une valeur fixee de k = 3
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# nb clusters =  3 , nb iter =  6 , runtime =  68.48  ms

# %%
import scipy.cluster.hierarchy as shc
# Donnees dans datanp
print(" Dendrogramme ' single ' donnees initiales ")
linked_mat = shc.linkage(datanp,'single')
plt.figure(figsize = (12,12))
shc.dendrogram(linked_mat ,
orientation = 'top' ,
distance_sort = 'descending',
show_leaf_counts = False )
plt.show()
# Out:
#  Dendrogramme ' single ' donnees initiales
